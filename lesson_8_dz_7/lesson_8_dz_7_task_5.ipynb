# %%
from matplotlib import pylab as plt
import numpy as np
# %matplotlib inline

# %%
plt.figure(figsize=(4,4))
plt.axis([0, 20, -4, 4])

x=np.linspace(0, 20, 200)
y1=-np.cos(x)+0.5*np.sin(x)+1
y2=2*np.sin(x)+np.cos(x)

plt.plot(x,y1, c='b')
plt.plot(x,y2, c='r')
plt.show()
